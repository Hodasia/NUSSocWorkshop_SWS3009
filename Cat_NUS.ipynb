# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 627.5/627.5 kB 34.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# 手动上传压缩文件包，然后用下面的命令解压

# %%
# !unzip 'Cat2.0.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: datasets/train/labels/Persian057.txt
#   inflating: __MACOSX/datasets/train/labels/._Persian057.txt
#   inflating: datasets/train/labels/cat143.txt
#   inflating: __MACOSX/datasets/train/labels/._cat143.txt
#   inflating: datasets/train/labels/45031614_60.txt
#   inflating: __MACOSX/datasets/train/labels/._45031614_60.txt
#   inflating: datasets/train/labels/48WABQFAVBJE.txt
#   inflating: __MACOSX/datasets/train/labels/._48WABQFAVBJE.txt
#   inflating: datasets/train/labels/Ragdoll198.txt
#   inflating: __MACOSX/datasets/train/labels/._Ragdoll198.txt
#   inflating: datasets/train/labels/34260326_351.txt
#   inflating: __MACOSX/datasets/train/labels/._34260326_351.txt
#   inflating: datasets/train/labels/Ragdoll167.txt
#   inflating: __MACOSX/datasets/train/labels/._Ragdoll167.txt
#   inflating: datasets/train/labels/Ragdoll173.txt
#   inflating: __MACOSX/datasets/train/labels/._Ragdoll173.txt
# ...

# %%
# !ls
# Out:
# Cat2.0.zip  cat_yolo.yaml  datasets  __MACOSX  sample_data

# %%
# !yolo train data=cat_yolo.yaml model=yolov8x.pt imgsz=256
# Out:
# Ultralytics YOLOv8.0.132 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !zip -r runs_result runs
# Out:
#   adding: runs/ (stored 0%)
#   adding: runs/detect/ (stored 0%)
#   adding: runs/detect/train/ (stored 0%)
#   adding: runs/detect/train/weights/ (stored 0%)
#   adding: runs/detect/train/args.yaml (deflated 51%)
#   adding: runs/detect/train2/ (stored 0%)
#   adding: runs/detect/train2/weights/ (stored 0%)
#   adding: runs/detect/train2/weights/best.pt (deflated 8%)
#   adding: runs/detect/train2/weights/last.pt (deflated 8%)
#   adding: runs/detect/train2/R_curve.png (deflated 10%)
#   adding: runs/detect/train2/args.yaml (deflated 51%)
#   adding: runs/detect/train2/events.out.tfevents.1689039093.81833972845c.2459.0 (deflated 72%)
#   adding: runs/detect/train2/train_batch1.jpg (deflated 7%)
#   adding: runs/detect/train2/val_batch1_labels.jpg (deflated 18%)
#   adding: runs/detect/train2/P_curve.png (deflated 11%)
#   adding: runs/detect/train2/train_batch9722.jpg (deflated 13%)
#   adding: runs/detect/train2/results.png (deflated 8%)
# ...

# %%
# !zip -r datasets_result datasets
# Out:
#   adding: datasets/ (stored 0%)
#   adding: datasets/train/ (stored 0%)
#   adding: datasets/train/.DS_Store (deflated 90%)
#   adding: datasets/train/images/ (stored 0%)
#   adding: datasets/train/images/Scottish_fold46.jpg (deflated 0%)
#   adding: datasets/train/images/Spythx180.jpg (deflated 5%)
#   adding: datasets/train/images/STR9SDG3TQGW.jpg (deflated 1%)
#   adding: datasets/train/images/cat078.jpg (deflated 1%)
#   adding: datasets/train/images/cat437.jpg (deflated 2%)
#   adding: datasets/train/images/cat228.jpg (deflated 2%)
#   adding: datasets/train/images/Persian214.jpg (deflated 1%)
#   adding: datasets/train/images/Ragdoll138.jpg (deflated 0%)
#   adding: datasets/train/images/Persian181.jpg (deflated 0%)
#   adding: datasets/train/images/Scottish_fold59.jpg (deflated 1%)
#   adding: datasets/train/images/Persian184.jpg (deflated 4%)
#   adding: datasets/train/images/cat169.jpg (deflated 1%)
#   adding: datasets/train/images/cat336.jpg (deflated 1%)
# ...

# %%
# !ls
# Out:
# Cat2.0.zip     datasets		    __MACOSX  runs_result.zip  yolov8n.pt
# cat_yolo.yaml  datasets_result.zip  runs      sample_data      yolov8x.pt

# %%
# !yolo
